# %%
import requests
from utils import check_api_call_limit
from dotenv import load_dotenv
import os 
import time
load_dotenv()
# Load the api key from dotenv:
GOOGLE_API_KEY = os.getenv('GOOGLE_MAPS_API_KEY')
if not GOOGLE_API_KEY:
    raise ValueError("No API key found. Please set the GOOGLE_MAPS_API_KEY environment variable in the .env file.")

# %%
# Lets try using the google places nearby search 
# In order to do that we need to have a lat and lng
# To get lat and lng we can use a few different sources: 
# I'm just going to use the google geocode api for now

import googlemaps
gmaps = googlemaps.Client(key=GOOGLE_API_KEY)
wellesly = gmaps.geocode(f"{'02481'}, USA")

# %%
import json
#print(json.dumps(wellesly, indent=4))
print(wellesly[0]['geometry']['location'])
# Out:
# {'lat': 42.3093812, 'lng': -71.28148159999999}

# %%
import googlemaps
gmaps = googlemaps.Client(key=GOOGLE_API_KEY)
wellesly2 = gmaps.geocode(f"{'02482'}, USA")
print(wellesly2[0]['geometry']['location'])
# Out:
# {'lat': 42.2904637, 'lng': -71.2963297}

# %%
import googlemaps
import requests
import time
from utils import check_api_call_limit

def get_car_washes_by_zip(api_key:str, zip_codes: str | list[str], zipcode_radius: int = 5000):
    """
    Fetch car washes for one or more zip codes using Google Places API Nearby Search.
    Includes deduplication based on place_id.

    Args:
        api_key (str): Google Maps API key.
        zip_codes (str or list): Single zip code or list of zip codes.
        zipcode_radius (int): The radius of the search in meters. Defaults to 5000.

    Returns:
        list: Car wash info (name, address, rating, etc.) if successful.
        dict: Error details if API limit exceeded.
    """
    if isinstance(zip_codes, str):  # If the zip_codes is a string, convert it to a list
        zip_codes = [zip_codes]

    gmaps = googlemaps.Client(key=api_key)
    places_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    all_car_washes = {}  # Use a dictionary to store unique car washes (for deduplication)

    for zip_code in zip_codes:
        print(f"Getting coordinates for car washes in {zip_code}", end="...")
        try:
            # Fetch the coordinates for the zip code from the google geocode api
            geocode_result = gmaps.geocode(f"{zip_code}, USA")
            if not geocode_result:
                print(f"Could not find coordinates for zip code {zip_code}")
                continue
            
            # Extract the latitude and longitude from the geocode result
            location = geocode_result[0]['geometry']['location']
        except Exception as e:
            print(f"Error geocoding zip code {zip_code}: {str(e)}")
            continue
        print("done.")

        # Define the parameters for the nearby search
        params = {
            "key": api_key,
            "location": f"{location['lat']},{location['lng']}",
            "radius": zipcode_radius,  # The radius of the search in meters
            "type": "car_wash",
            "keyword": "car wash"
        }
        
        next_page_token = None
        callcount = 0

        while True:
            # Check API call limit before making the next request
            success, message, counts = check_api_call_limit("nearby_search", daily_limit=600, monthly_limit=5800)
            if not success:
                return {"error": f"Limit exceeded: {message}. Total calls: {counts['total_calls']}, Monthly calls: {counts['monthly_calls']}, Daily calls: {counts['daily_calls']}."}

            if next_page_token:
                params["pagetoken"] = next_page_token
            
            print(f"Searching for car washes with 5km radius around {location}", end="...")
            response = requests.get(places_url, params=params)
            results = response.json()
            
            if results.get("status") != "OK":
                print(f"Error for zip code {zip_code}: {results.get('status')}")
                break
            
            for place in results.get("results", []):
                place_id = place['place_id']
                if place_id not in all_car_washes:
                    all_car_washes[place_id] = {
                        "name": place["name"],
                        "address": place.get("vicinity"),
                        "goog_rating": place.get("rating"),
                        "lat": place["geometry"]["location"]["lat"],
                        "lng": place["geometry"]["location"]["lng"],
                        "goog_places_id": place_id,
                        "zip_codes": [zip_code]  # Start a list of associated zip codes
                    }
                else:
                    # If the car wash already exists, just add the current zip code to its list
                    if zip_code not in all_car_washes[place_id]["zip_codes"]:
                        all_car_washes[place_id]["zip_codes"].append(zip_code)
            
            next_page_token = results.get("next_page_token")
            callcount += 1
            if not next_page_token or callcount >= 3:  # Limit to 3 pages per zip code
                print("done.")
                break
                
            # Wait before making the next request (to comply with API usage limits)
            time.sleep(2)

    print(f"Number of zip codes searched: {len(zip_codes)}")
    print(f"Number of car washes found: {len(list(all_car_washes.values()))}")
    # Convert the dictionary of unique car washes back to a list
    return {'results': list(all_car_washes.values()), 'num_results': len(list(all_car_washes.values())), 'num_zip_codes': len(zip_codes)}

# %%
get_car_washes_by_zip(GOOGLE_API_KEY, ['2301', '2148', '2155', '2360', '2169', '2151', '2124', '1960', '1844', '1841', '1902', '2780', '2149',])
# Out:
# Getting coordinates for car washes in 2301...done.
# Searching for car washes with 5km radius around {'lat': 42.0725522, 'lng': -71.0378909}...done.
# Getting coordinates for car washes in 2148...done.
# Searching for car washes with 5km radius around {'lat': 42.4326041, 'lng': -71.0557196}...done.
# Getting coordinates for car washes in 2155...done.
# Searching for car washes with 5km radius around {'lat': 42.4274971, 'lng': -71.10920120000002}...done.
# Getting coordinates for car washes in 2360...done.
# Searching for car washes with 5km radius around {'lat': 41.8804637, 'lng': -70.645473}...Error for zip code 2360: ZERO_RESULTS
# Getting coordinates for car washes in 2169...done.
# Searching for car washes with 5km radius around {'lat': 42.25136819999999, 'lng': -70.9962875}...done.
# Getting coordinates for car washes in 2151...done.
# Searching for car washes with 5km radius around {'lat': 42.4224283, 'lng': -70.9962875}...done.
# Getting coordinates for car washes in 2124...done.
# Searching for car washes with 5km radius around {'lat': 42.2826027, 'lng': -71.067605}...done.
# Getting coordinates for car washes in 1960...done.
# Searching for car washes with 5km radius around {'lat': 38.7945952, 'lng': -106.5348379}...Error for zip code 1960: ZERO_RESULTS
# Getting coordinates for car washes in 1844...done.
# Searching for car washes with 5km radius around {'lat': 42.7276358, 'lng': -71.20426189999999}...Searching for car washes with 5km radius around {'lat': 42.7276358, 'lng': -71.20426189999999}...done.
# Getting coordinates for car washes in 1841...done.
# Searching for car washes with 5km radius around {'lat': 42.7139972, 'lng': -71.1656462}...Searching for car washes with 5km radius around {'lat': 42.7139972, 'lng': -71.1656462}...done.
# Getting coordinates for car washes in 1902...done.
# Searching for car washes with 5km radius around {'lat': 42.4719938, 'lng': -70.9398192}...done.
# Getting coordinates for car washes in 2780...done.
# Searching for car washes with 5km radius around {'lat': 41.9241038, 'lng': -71.121085}...done.
# Getting coordinates for car washes in 2149...done.
# Searching for car washes with 5km radius around {'lat': 42.4041313, 'lng': -71.0557196}...Searching for car washes with 5km radius around {'lat': 42.4041313, 'lng': -71.0557196}...done.
# Number of zip codes searched: 13
# Number of car washes found: 119
# {'results': [{'name': 'Fresh Auto Wash',
#    'address': '105 Depot St, South Easton',
#    'goog_rating': 4,
#    'lat': 42.042648,
#    'lng': -71.0769825,
#    'goog_places_id': 'ChIJi2aX5FyP5IkRX7lggkAfA3g',
#    'zip_codes': ['2301']},
#   {'name': "Sunny's Car Wash",
#    'address': '547 Westgate Dr, Brockton',
#    'goog_rating': 3.5,
#    'lat': 42.0918451,
#    'lng': -71.0532332,
#    'goog_places_id': 'ChIJCfJl_laE5IkRE9V8I0uQcac',
#    'zip_codes': ['2301']},
#   {'name': 'Suds Plus Car Wash',
#    'address': '795 Centre St, Brockton',
#    'goog_rating': 4,
#    'lat': 42.08672019999999,
#    'lng': -70.985326,
#    'goog_places_id': 'ChIJ0x0dwzub5IkRSzm-iPpwWlg',
#    'zip_codes': ['2301']},
#   {'name': 'Prestige Car Wash (Brockton)',
#    'address': '245 N Pearl St, Brockton',
#    'goog_rating': 4.5,
#    'lat': 42.098091,
#    'lng': -71.06555,
#    'goog_places_id': 'ChIJWx_ztkWE5IkR9pEyAePesUE',
#    'zip_codes': ['2301']},
#   {'name': 'Bubble Bay Car Wash',
#    'address': '1015 Main St, Brockton',
#    'goog_rating': 4.8,
#    'lat': 42.0652871,
#    'lng': -71.0164648,
#    'goog_places_id': 'ChIJJ5oDGRWF5IkR5HQ8nKQsQhA',
#    'zip_codes': ['2301']},
#   {'name': 'Buff & Shine',
#    'address': '790 N Main St, West Bridgewater',
#    'goog_rating': 3,
#    'lat': 42.0415601,
#    'lng': -71.0093332,
#    'goog_places_id': 'ChIJ4Q_Qi1aF5IkRlnwB__fVQko',
#    'zip_codes': ['2301']},
#   {'name': "Sunny's Car Wash",
#    'address': '1075 N Montello St, Brockton',
#    'goog_rating': 3.7,
#    'lat': 42.1132572,
#    'lng': -71.02754469999999,
#    'goog_places_id': 'ChIJX_w6yJiE5IkRXggmEoROgOY',
#    'zip_codes': ['2301']},
#   {'name': 'Shell',
#    'address': '253 E Ashland St, Brockton',
#    'goog_rating': 3.7,
#    'lat': 42.0961591,
#    'lng': -71.007894,
#    'goog_places_id': 'ChIJYbcHAMqE5IkRtsUJ7zkmE_k',
#    'zip_codes': ['2301']},
#   {'name': 'Sparkling Image Car Wash',
#    'address': '1970 Revere Beach Pkwy, Everett',
#    'goog_rating': 4.1,
#    'lat': 42.4027863,
#    'lng': -71.052757,
#    'goog_places_id': 'ChIJoTwhdAlx44kRIO9vpyJcMW4',
#    'zip_codes': ['2148', '2155', '2151', '2149']},
#   {'name': 'Sparkling Image Car Wash',
#    'address': '435 Eastern Ave, Malden',
#    'goog_rating': 3.9,
#    'lat': 42.4277936,
#    'lng': -71.0573278,
#    'goog_places_id': 'ChIJU7T9jX1x44kRgn6iDl3k6JA',
#    'zip_codes': ['2148', '2155', '2151', '2149']},
#   {'name': 'ScrubaDub Car Wash',
#    'address': '294 Eastern Ave, Chelsea',
#    'goog_rating': 4.4,
#    'lat': 42.3963972,
#    'lng': -71.0216222,
#    'goog_places_id': 'ChIJW8tsjcZx44kRLkyvdO_cErk',
#    'zip_codes': ['2148', '2151', '2149']},
#   {'name': 'Prestige Car Wash (Malden)',
#    'address': '62 Broadway, Malden',
#    'goog_rating': 4.9,
#    'lat': 42.4254956,
#    'lng': -71.0421306,
#    'goog_places_id': 'ChIJ0SKGGdZx44kRWVnxxTN-lvc',
#    'zip_codes': ['2148', '2151', '2149']},
#   {'name': 'Prestige Car Wash (Medford)',
#    'address': '277 Middlesex Ave, Medford',
#    'goog_rating': 4.5,
#    'lat': 42.4125289,
#    'lng': -71.07855219999999,
#    'goog_places_id': 'ChIJt1XcTT9x44kRufkPmh7HK2k',
#    'zip_codes': ['2148', '2155', '2149']},
#   {'name': 'Barn Car Wash',
#    'address': '110 Frank P Bennett Hwy, Saugus',
#    'goog_rating': 4.6,
#    'lat': 42.4471875,
#    'lng': -71.023935,
#    'goog_places_id': 'ChIJe0-vlWly44kRG0uXW_mTjTc',
#    'zip_codes': ['2148', '2151', '2149']},
#   {'name': 'Prestige Car Wash (Melrose)',
#    'address': '186 Tremont St, Melrose',
#    'goog_rating': 3.8,
#    'lat': 42.4656722,
#    'lng': -71.06904420000001,
#    'goog_places_id': 'ChIJMRxgH6Fz44kRc4euRlfmsOI',
#    'zip_codes': ['2148', '2155']},
#   {'name': 'Barn Car Wash',
#    'address': '1141 Revere Beach Pkwy, Revere',
#    'goog_rating': 4.5,
#    'lat': 42.4074658,
#    'lng': -71.0253038,
#    'goog_places_id': 'ChIJg49r3lRx44kRuKgW9uphq7Q',
#    'zip_codes': ['2148', '2151', '2149']},
#   {'name': 'Titan Gas & Car Wash',
#    'address': '590 Boston Ave, Medford',
#    'goog_rating': 4.2,
#    'lat': 42.4027247,
#    'lng': -71.1134514,
#    'goog_places_id': 'ChIJ_Wf-GNl244kRlvf9iiP3BoI',
#    'zip_codes': ['2148', '2155', '2149']},
#   {'name': 'Barn Car Wash',
#    'address': '95 Squire Rd, Revere',
#    'goog_rating': 4.4,
#    'lat': 42.4229983,
#    'lng': -71.0075908,
#    'goog_places_id': 'ChIJZUT-YgFy44kRJMxdvjB8JNo',
#    'zip_codes': ['2148', '2151', '2149']},
#   {'name': 'Rivera Power Wash Car Detail Inc.',
#    'address': '15 Veterans Ave, Everett',
#    'goog_rating': 3.8,
#    'lat': 42.4147131,
#    'lng': -71.0419758,
#    'goog_places_id': 'ChIJwYvj961x44kRZWqnsYpPokw',
#    'zip_codes': ['2148', '2151', '2149']},
#   {'name': 'Riverside Automobile Detail',
#    'address': '504 Riverside Ave, Medford',
#    'goog_rating': 4.3,
#    'lat': 42.4101768,
#    'lng': -71.0855244,
#    'goog_places_id': 'ChIJayFGXzdx44kRAN3b8iEmY2I',
#    'zip_codes': ['2148', '2155', '2149']},
#   {'name': 'Carwash Touch Fres',
#    'address': '870 Main St, Melrose',
#    'goog_rating': 3,
#    'lat': 42.4644553,
#    'lng': -71.06204430000001,
#    'goog_places_id': 'ChIJWYeX1Kdz44kRCOycadWehCk',
#    'zip_codes': ['2148']},
#   {'name': 'Shamrock Auto Detailing & Ceramic Coating',
#    'address': '100 Tremont St, Everett',
#    'goog_rating': 5,
#    'lat': 42.4108319,
#    'lng': -71.0673729,
#    'goog_places_id': 'ChIJkV8VDBp344kR2ctMYJsjgZo',
#    'zip_codes': ['2148', '2149']},
#   {'name': 'Perfect Car Detailing',
#    'address': '79 Stanton Ave, Revere',
#    'goog_rating': 0,
#    'lat': 42.418586,
#    'lng': -71.00309519999999,
#    'goog_places_id': 'ChIJt7gYXvRx44kRikU1PJqEo64',
#    'zip_codes': ['2148', '2151', '2149']},
#   {'name': 'Prestige Car Wash (Somerville)',
#    'address': '680 Somerville Ave, Somerville',
#    'goog_rating': 4.6,
#    'lat': 42.3851968,
#    'lng': -71.11325910000001,
#    'goog_places_id': 'ChIJAwaF4Tt344kRtE44-J9E818',
#    'zip_codes': ['2155', '2149']},
#   {'name': 'Shield System Car Wash',
#    'address': '783 Main St, Winchester',
#    'goog_rating': 4.1,
#    'lat': 42.4587653,
#    'lng': -71.13944289999999,
#    'goog_places_id': 'ChIJx0SvLTR044kRAv4pqFq7yBc',
#    'zip_codes': ['2155']},
#   {'name': 'Somerville No Touch Car Wash',
#    'address': '31 Washington St, Somerville',
#    'goog_rating': 3.8,
#    'lat': 42.382025,
#    'lng': -71.0825435,
#    'goog_places_id': 'ChIJawa-ssVw44kRPZRALCdPaB0',
#    'zip_codes': ['2155', '2149']},
#   {'name': "Lord's Auto Detailing",
#    'address': '111 Chelsea St, Everett',
#    'goog_rating': 4.8,
#    'lat': 42.4047571,
#    'lng': -71.0512419,
#    'goog_places_id': 'ChIJs8jjMgtx44kRkZPnbZHMVcM',
#    'zip_codes': ['2155']},
#   {'name': 'Viper Car Detailing - Mobile Car Detailing | Ceramic Coating',
#    'address': '165 Middlesex Ave #1137, Somerville',
#    'goog_rating': 4.9,
#    'lat': 42.3960971,
#    'lng': -71.08369069999999,
#    'goog_places_id': 'ChIJg8vsyEDzskkRzzmJOnZlFO4',
#    'zip_codes': ['2155']},
#   {'name': 'Prestige Car Wash (Quincy)',
#    'address': '645 Washington St, Quincy',
#    'goog_rating': 4.8,
#    'lat': 42.24595,
#    'lng': -70.9751426,
#    'goog_places_id': 'ChIJtTOOHUNj44kReVBooas7ljM',
#    'zip_codes': ['2169']},
#   {'name': 'ScrubaDub Car Wash',
#    'address': '147 Coddington St, Quincy',
#    'goog_rating': 4.5,
#    'lat': 42.2547582,
#    'lng': -70.9968679,
#    'goog_places_id': 'ChIJiSjW3k1j44kR4VfQICMAc_Q',
#    'zip_codes': ['2169']},
#   {'name': 'Super Shine Auto Wash',
#    'address': '259 Union St #4905, Braintree',
#    'goog_rating': 3.7,
#    'lat': 42.2109874,
#    'lng': -70.99383449999999,
#    'goog_places_id': 'ChIJY_rZBcli44kRG0gKmv9SDuM',
#    'zip_codes': ['2169']},
#   {'name': 'Neponset Circle Car Wash',
#    'address': '815 Gallivan Blvd, Dorchester',
#    'goog_rating': 4.3,
#    'lat': 42.2852518,
#    'lng': -71.04259050000002,
#    'goog_places_id': 'ChIJZYw0J3F744kRwZIzg77PVmA',
#    'zip_codes': ['2169', '2124']},
#   {'name': 'Hancock Street Touchless Car Wash',
#    'address': '839 Hancock St, Quincy',
#    'goog_rating': 3.7,
#    'lat': 42.2625288,
#    'lng': -71.012192,
#    'goog_places_id': 'ChIJYZbDG69844kRfsXPuYd9ULE',
#    'zip_codes': ['2169', '2124']},
#   {'name': 'SUPERSHINE GRANITE ST',
#    'address': '4 Granite St, Braintree',
#    'goog_rating': 4,
#    'lat': 42.2278689,
#    'lng': -71.03128269999999,
#    'goog_places_id': 'ChIJbR6pXBl944kRoV3jgXDLVQA',
#    'zip_codes': ['2169']},
#   {'name': 'South Shore Car Wash Inc',
#    'address': '384 Centre St, Quincy',
#    'goog_rating': 3.9,
#    'lat': 42.2338558,
#    'lng': -71.01046529999999,
#    'goog_places_id': 'ChIJE7Ya3NZ844kRHrBS3gLMhEI',
#    'zip_codes': ['2169']},
#   {'name': 'Super Clean Car Wash',
#    'address': '2 Miller St, Quincy',
#    'goog_rating': 3.5,
#    'lat': 42.2429992,
#    'lng': -71.02357099999999,
#    'goog_places_id': 'ChIJ4_kp58J844kRbJtxd22fAGo',
#    'zip_codes': ['2169', '2124']},
#   {'name': 'Supershine Auto Wash',
#    'address': '697 Bridge St, North Weymouth',
#    'goog_rating': 3.8,
#    'lat': 42.24464,
#    'lng': -70.9379131,
#    'goog_places_id': 'ChIJ4-3nk5Fj44kRbWFSeRjGnzE',
#    'zip_codes': ['2169']},
#   {'name': 'Car Detailing Braintree',
#    'address': '71 Shaw St, Braintree',
#    'goog_rating': 4.9,
#    'lat': 42.222362,
#    'lng': -70.9726469,
#    'goog_places_id': 'ChIJzxK9CMRj44kRh3E7EdWbcGY',
#    'zip_codes': ['2169']},
#   {'name': 'Car Detailing Quincy ( Quincy Car Detailing & Car Wash )',
#    'address': '38 Whitwell St, Quincy',
#    'goog_rating': 3.5,
#    'lat': 42.2520925,
#    'lng': -71.0170622,
#    'goog_places_id': 'ChIJI6ClusR944kRjwHg63K2eDk',
#    'zip_codes': ['2169', '2124']},
#   {'name': 'Touch Free Car Wash',
#    'address': '185 Washington St, Weymouth',
#    'goog_rating': 1,
#    'lat': 42.21639589999999,
#    'lng': -70.9642616,
#    'goog_places_id': 'ChIJV2b0cfti44kRS_662PE2USw',
#    'zip_codes': ['2169']},
#   {'name': 'High Tech Detailing & Dry Ice Blasting & Ceramic coating',
#    'address': 'Rear of building, 198 Bridge St, Weymouth',
#    'goog_rating': 4.9,
#    'lat': 42.242895,
#    'lng': -70.95749959999999,
#    'goog_places_id': 'ChIJU-QYtKNj44kRf968abin7zg',
#    'zip_codes': ['2169']},
#   {'name': 'Shell',
#    'address': '185 Washington St, Weymouth',
#    'goog_rating': 3.3,
#    'lat': 42.2166915,
#    'lng': -70.9644529,
#    'goog_places_id': 'ChIJ9yNfbvti44kRdqmmkxN3kz0',
#    'zip_codes': ['2169']},
#   {'name': 'Golden Nozzle Car Wash',
#    'address': '535 Lynnway, Lynn',
#    'goog_rating': 4,
#    'lat': 42.4559587,
#    'lng': -70.9584895,
#    'goog_places_id': 'ChIJXSxGR0Nt44kR5IXEWE-vGlE',
#    'zip_codes': ['2151', '1902']},
#   {'name': 'Sonny’s Car Wash',
#    'address': '30A Main St, Winthrop',
#    'goog_rating': 4.5,
#    'lat': 42.3830528,
#    'lng': -70.9932115,
#    'goog_places_id': 'ChIJhxV9SCxu44kRNRI2-wUaqK4',
#    'zip_codes': ['2151', '2149']},
#   {'name': 'Sparkling Image Car Wash',
#    'address': '700 Lynnway, Lynn',
#    'goog_rating': 4.2,
#    'lat': 42.451398,
#    'lng': -70.96181240000001,
#    'goog_places_id': 'ChIJexniGQdt44kRrlF3uF5wIhc',
#    'zip_codes': ['2151', '1902']},
#   {'name': 'Squikee Clean Car Wash',
#    'address': '452 Bremen St, Boston',
#    'goog_rating': 3.8,
#    'lat': 42.3798606,
#    'lng': -71.0262693,
#    'goog_places_id': 'ChIJdSsn-Ulw44kRBX2Tf4JTrFQ',
#    'zip_codes': ['2151', '2149']},
#   {'name': 'A-1 Crystal Clean Services LLC',
#    'address': '1070 Western Ave, Lynn',
#    'goog_rating': 4.5,
#    'lat': 42.4546431,
#    'lng': -70.974728,
#    'goog_places_id': 'ChIJ0zB-zvxs44kR-ar36bndsF0',
#    'zip_codes': ['2151', '1902']},
#   {'name': 'The plan B, Auto Detailing',
#    'address': '10 Heaths Ct #5, Lynn',
#    'goog_rating': 5,
#    'lat': 42.454147,
#    'lng': -70.97805199999999,
#    'goog_places_id': 'ChIJvRcI8klt44kR7Sy7kPi9kPM',
#    'zip_codes': ['2151', '1902']},
#   {'name': "Sonny's Car Wash",
#    'address': 'Harding St, Lynn',
#    'goog_rating': 3,
#    'lat': 42.4514344,
#    'lng': -70.9619998,
#    'goog_places_id': 'ChIJLcYVPQdt44kR2-Ew12Sh3tg',
#    'zip_codes': ['2151', '1902']},
#   {'name': 'new england detailing',
#    'address': '8 Bennett St, Lynn',
#    'goog_rating': 4.9,
#    'lat': 42.4572302,
#    'lng': -70.9589391,
#    'goog_places_id': 'ChIJGT9BrbBt44kRvodU7P45J08',
#    'zip_codes': ['2151', '1902']},
#   {'name': 'Jamaica Plain Car Wash',
#    'address': '3530 Washington St, Jamaica Plain',
#    'goog_rating': 4.1,
#    'lat': 42.3053434,
#    'lng': -71.1082194,
#    'goog_places_id': 'ChIJR78uxWd544kRaEooGbVAewY',
#    'zip_codes': ['2124']},
#   {'name': 'A C Hand Car Wash',
#    'address': '21 Geneva Ave, Dorchester',
#    'goog_rating': 4.3,
#    'lat': 42.3083462,
#    'lng': -71.08211969999999,
#    'goog_places_id': 'ChIJsyBshMV744kRR5T_fXgwGB8',
#    'zip_codes': ['2124']},
#   {'name': 'Fernandez Xpress Car wash',
#    'address': '1480 Blue Hill Ave, Boston',
#    'goog_rating': 4.2,
#    'lat': 42.2735425,
#    'lng': -71.0933077,
#    'goog_places_id': 'ChIJhZ4fPAN844kRoobYbXiMP8A',
#    'zip_codes': ['2124']},
#   {'name': 'Mattapan Car Wash & Quick Lube',
#    'address': '1480 Blue Hill Ave, Mattapan',
#    'goog_rating': 4.3,
#    'lat': 42.2738269,
#    'lng': -71.0929941,
#    'goog_places_id': 'ChIJB0kHPAN844kRrPXtQ2xsi0E',
#    'zip_codes': ['2124']},
#   {'name': 'All cars detail',
#    'address': '15 Harding Rd, Roslindale',
#    'goog_rating': 4.4,
#    'lat': 42.2800636,
#    'lng': -71.11758549999999,
#    'goog_places_id': 'ChIJq6p28bZ-44kRn2FFVHWR4gI',
#    'zip_codes': ['2124']},
#   {'name': 'ScrubaDub Car Wash',
#    'address': '25 W Howell St, Dorchester',
#    'goog_rating': 4.4,
#    'lat': 42.3257397,
#    'lng': -71.0599421,
#    'goog_places_id': 'ChIJDxRR6Fp644kRDwRrhtVaHWE',
#    'zip_codes': ['2124']},
#   {'name': 'ScrubaDub Car Wash',
#    'address': '565 American Legion Hwy, Roslindale',
#    'goog_rating': 4.2,
#    'lat': 42.28736689999999,
#    'lng': -71.1085162,
#    'goog_places_id': 'ChIJoTP9iVJ544kRayuXfgDWtLA',
#    'zip_codes': ['2124']},
#   {'name': 'Emporium Gas',
#    'address': '3875 Washington St, Boston',
#    'goog_rating': 4,
#    'lat': 42.2959254,
#    'lng': -71.118331,
#    'goog_places_id': 'ChIJC_YZ1kd544kRy7H_84ahJr0',
#    'zip_codes': ['2124']},
#   {'name': 'Fluffed & Buffed',
#    'address': '120 Business St # 1, Hyde Park',
#    'goog_rating': 4.4,
#    'lat': 42.2508146,
#    'lng': -71.13025859999999,
#    'goog_places_id': 'ChIJU5kczfd-44kRsN_iywByuGo',
#    'zip_codes': ['2124']},
#   {'name': 'Teneus.Touch',
#    'address': '8 Allstate Rd, Dorchester',
#    'goog_rating': 0,
#    'lat': 42.3272047,
#    'lng': -71.0613417,
#    'goog_places_id': 'ChIJDaZ8_qx744kR4EtdrH0nIZc',
#    'zip_codes': ['2124']},
#   {'name': "Haffner's Gentle Touch Car Wash",
#    'address': '330 S Broadway, Lawrence',
#    'goog_rating': 4.3,
#    'lat': 42.6890733,
#    'lng': -71.1580992,
#    'goog_places_id': 'ChIJETHvSsYH44kR4aglybbyC-8',
#    'zip_codes': ['1844', '1841']},
#   {'name': "Haffner's Gentle Touch",
#    'address': '96 Pleasant Valley St, Methuen',
#    'goog_rating': 4.2,
#    'lat': 42.7433373,
#    'lng': -71.1530427,
#    'goog_places_id': 'ChIJiZN3e8sD44kRWCybLgZkce8',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Wash, Wax and Wheels Car Wash',
#    'address': '2 Baldwin St, Methuen',
#    'goog_rating': 4.2,
#    'lat': 42.7292528,
#    'lng': -71.2069322,
#    'goog_places_id': 'ChIJi0W2dMWp44kRz_azeJEP5ic',
#    'zip_codes': ['1844', '1841']},
#   {'name': "Klemm's Express CarWash",
#    'address': '4 Mall Rd, Salem',
#    'goog_rating': 4.3,
#    'lat': 42.7693178,
#    'lng': -71.2293634,
#    'goog_places_id': 'ChIJmS9KV8Gr44kRtyqztTQ7tTc',
#    'zip_codes': ['1844']},
#   {'name': "Enzo's Car Wash",
#    'address': '171 Jackson St, Lawrence',
#    'goog_rating': 4.9,
#    'lat': 42.7135366,
#    'lng': -71.1577528,
#    'goog_places_id': 'ChIJH9SOAZYH44kRMP03sdJfu4Y',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Max Power Car Wash',
#    'address': '137 Jackson St, Lawrence',
#    'goog_rating': 5,
#    'lat': 42.7128382,
#    'lng': -71.15750799999999,
#    'goog_places_id': 'ChIJbdIwxeQH44kRTM4Asj7DJ8M',
#    'zip_codes': ['1844', '1841']},
#   {'name': "Haffner's Car Wash",
#    'address': '440 S Broadway, Salem',
#    'goog_rating': 4.3,
#    'lat': 42.7471826,
#    'lng': -71.20342649999999,
#    'goog_places_id': 'ChIJq4FzwPqp44kRK99vdaB7Lc4',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'High Tide Car Wash',
#    'address': '69 S Broadway, Salem',
#    'goog_rating': 4.6,
#    'lat': 42.77473699999999,
#    'lng': -71.2240364,
#    'goog_places_id': 'ChIJXcXbbjmq44kRmopIKId3D4Q',
#    'zip_codes': ['1844']},
#   {'name': 'Black Diamond Auto Detailing',
#    'address': '235 Walnut St, Lawrence',
#    'goog_rating': 5,
#    'lat': 42.72040459999999,
#    'lng': -71.1704683,
#    'goog_places_id': 'ChIJTTtrHZcH44kRgSSJtpu7FEI',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Washville Car Wash',
#    'address': '464 Broadway, Methuen',
#    'goog_rating': 4.4,
#    'lat': 42.738323,
#    'lng': -71.196133,
#    'goog_places_id': 'ChIJu-OweSmp44kRkOqIzj91BOU',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Smart Wash Mobile Car Detailing',
#    'address': '35 E Brook Pl, Methuen',
#    'goog_rating': 4.9,
#    'lat': 42.7229152,
#    'lng': -71.16801029999999,
#    'goog_places_id': 'ChIJ82fXyBIH44kRmxIKZ7KJkJ0',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Merrimac Laundromat & Car Wash',
#    'address': '21 Burnham Rd, Methuen',
#    'goog_rating': 4.5,
#    'lat': 42.7050283,
#    'lng': -71.20239889999999,
#    'goog_places_id': 'ChIJ06n56iSo44kRL81a5soZITk',
#    'zip_codes': ['1844', '1841']},
#   {'name': "Haffner's Car Wash",
#    'address': '469 Haverhill St, Lawrence',
#    'goog_rating': 4.2,
#    'lat': 42.706809,
#    'lng': -71.1757397,
#    'goog_places_id': 'ChIJC3zMzpsH44kReRlPsWClH14',
#    'zip_codes': ['1844', '1841']},
#   {'name': "Haffner's Car Wash",
#    'address': '69 Parker St, Lawrence',
#    'goog_rating': 0,
#    'lat': 42.6984935,
#    'lng': -71.1596579,
#    'goog_places_id': 'ChIJN7jkVZwH44kRQ_Ca_BPKVF0',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Flow Car Wash',
#    'address': 'Arlington St, Lawrence',
#    'goog_rating': 4.7,
#    'lat': 42.7206611,
#    'lng': -71.1699066,
#    'goog_places_id': 'ChIJLyVMv3IH44kR6vWxTgX__jw',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Jriel AutoDetailing & Custom Wrap',
#    'address': '37 Newbury St, Lawrence',
#    'goog_rating': 5,
#    'lat': 42.7090006,
#    'lng': -71.1554579,
#    'goog_places_id': 'ChIJ5f1p6-MH44kRzx8M1RGXWWc',
#    'zip_codes': ['1844', '1841']},
#   {'name': "D'Monster Car Wash-Detailing",
#    'address': '407 Canal St, Lawrence',
#    'goog_rating': 4,
#    'lat': 42.70607,
#    'lng': -71.1622117,
#    'goog_places_id': 'ChIJY0HoBqQH44kRfB0x5E_rJYM',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Circle K | Car Wash',
#    'address': '181 Pelham St, Methuen',
#    'goog_rating': 0,
#    'lat': 42.7296973,
#    'lng': -71.210343,
#    'goog_places_id': 'ChIJoVW-XSap44kRdegVPnvKz3c',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'MC MOBILE AUTO DETAIL LLC',
#    'address': '100 Tenney St, Methuen',
#    'goog_rating': 0,
#    'lat': 42.7217237,
#    'lng': -71.1773182,
#    'goog_places_id': 'ChIJxYOiKxMH44kR4wU2byYN-yE',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Rene CarWash',
#    'address': '61 Essex St, Lawrence',
#    'goog_rating': 0,
#    'lat': 42.7080758,
#    'lng': -71.1549021,
#    'goog_places_id': 'ChIJzX_B56UH44kRhqFZ_yEdkNI',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Exotic Car Wash',
#    'address': 'Lawrence',
#    'goog_rating': 0,
#    'lat': 42.712817,
#    'lng': -71.1573599,
#    'goog_places_id': 'ChIJgZeeiAgH44kRcqkmJxBSkLs',
#    'zip_codes': ['1844', '1841']},
#   {'name': "Haffner's Car Wash",
#    'address': '425 Merrimack St, Lawrence',
#    'goog_rating': 3,
#    'lat': 42.7029994,
#    'lng': -71.1432267,
#    'goog_places_id': 'ChIJcxJhYQAH44kR-NP-_grtRWE',
#    'zip_codes': ['1844', '1841']},
#   {'name': "Haffner's Gas Station and Car Wash",
#    'address': '69 Parker St, Lawrence',
#    'goog_rating': 4.1,
#    'lat': 42.6984947,
#    'lng': -71.15965709999999,
#    'goog_places_id': 'ChIJpyUbV7oH44kRxQ-fLec-FlA',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Quality Kings Auto Detailing & Car Wash',
#    'address': '79 Brook St, Lawrence',
#    'goog_rating': 5,
#    'lat': 42.7146483,
#    'lng': -71.155379,
#    'goog_places_id': 'ChIJD1NJro0H44kRij1ezfrWkCE',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Lowrece',
#    'address': '689 Essex St, Lawrence',
#    'goog_rating': 0,
#    'lat': 42.7026838,
#    'lng': -71.17377549999999,
#    'goog_places_id': 'ChIJE5o7ZgMH44kR5msOWhbycis',
#    'zip_codes': ['1844', '1841']},
#   {'name': "Jay's car wash services",
#    'address': 'Border St, Lawrence',
#    'goog_rating': 0,
#    'lat': 42.6929321,
#    'lng': -71.1659344,
#    'goog_places_id': 'ChIJf8SztH4H44kR_7NAYBDwy_0',
#    'zip_codes': ['1844', '1841']},
#   {'name': "Big Dave's Auto Detailing",
#    'address': '117 Cluff Crossing Rd, Salem',
#    'goog_rating': 0,
#    'lat': 42.7625196,
#    'lng': -71.22159189999999,
#    'goog_places_id': 'ChIJbwCwkzWr44kRvz7M3nj2u3c',
#    'zip_codes': ['1844']},
#   {'name': 'Express Detailing Supplies',
#    'address': 'May St, Lawrence',
#    'goog_rating': 5,
#    'lat': 42.7095134,
#    'lng': -71.1782053,
#    'goog_places_id': 'ChIJL59eCXkH44kRYIahwRTnSMs',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Circle K',
#    'address': '181 Pelham St, Methuen',
#    'goog_rating': 2.5,
#    'lat': 42.729961,
#    'lng': -71.210342,
#    'goog_places_id': 'ChIJHSDpCsap44kRkc5bmsuuKpM',
#    'zip_codes': ['1844']},
#   {'name': "Haffner's Gas Station",
#    'address': '96 Pleasant Valley St, Methuen',
#    'goog_rating': 3.8,
#    'lat': 42.74363169999999,
#    'lng': -71.1531407,
#    'goog_places_id': 'ChIJV09msy0H44kRjWmNztZ8uNE',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Solo Moto',
#    'address': '44 Myrtle St, Lawrence',
#    'goog_rating': 3.8,
#    'lat': 42.7146845,
#    'lng': -71.1665757,
#    'goog_places_id': 'ChIJ23zWPAsH44kReT6I6P0-1_w',
#    'zip_codes': ['1844', '1841']},
#   {'name': 'Prestige Car Wash',
#    'address': '10 Commerce Way, North Andover',
#    'goog_rating': 4.8,
#    'lat': 42.7166377,
#    'lng': -71.1149512,
#    'goog_places_id': 'ChIJtf3BY5wH44kR9MHxzavCL3w',
#    'zip_codes': ['1841']},
#   {'name': "Klemm's Express CarWash",
#    'address': '1200 Boston Rd, Haverhill',
#    'goog_rating': 4.3,
#    'lat': 42.74351840000001,
#    'lng': -71.10941009999999,
#    'goog_places_id': 'ChIJwZOiM7oB44kRhkLK0eCpxLk',
#    'zip_codes': ['1841']},
#   {'name': 'Self-Serve Wash',
#    'address': '1208 Boston Rd, Haverhill',
#    'goog_rating': 3.7,
#    'lat': 42.74349309999999,
#    'lng': -71.1099119,
#    'goog_places_id': 'ChIJT9Shkk0B44kR3t63bVHG6vA',
#    'zip_codes': ['1841']},
#   {'name': "Haffner's Gentle Touch",
#    'address': '564 Chickering Rd, North Andover',
#    'goog_rating': 4,
#    'lat': 42.6962402,
#    'lng': -71.1196093,
#    'goog_places_id': 'ChIJcR6zpWcG44kRKjG6bQK8QIY',
#    'zip_codes': ['1841']},
#   {'name': "Haffner's Gas Station and Car Wash",
#    'address': '564 Chickering Rd, North Andover',
#    'goog_rating': 4.1,
#    'lat': 42.6963053,
#    'lng': -71.1192147,
#    'goog_places_id': 'ChIJyymzpWcG44kRjeRyYwY0nqE',
#    'zip_codes': ['1841']},
#   {'name': 'Prestige Car Wash (Salem)',
#    'address': '51 Canal St, Salem',
#    'goog_rating': 4.5,
#    'lat': 42.5159652,
#    'lng': -70.89548429999999,
#    'goog_places_id': 'ChIJ8_j6Ln0U44kRrQfP2jVuqRk',
#    'zip_codes': ['1902']},
#   {'name': 'Triton Wash Car Care Center',
#    'address': '232 Highland Ave, Salem',
#    'goog_rating': 4.3,
#    'lat': 42.5051327,
#    'lng': -70.9218959,
#    'goog_places_id': 'ChIJqcHNO28T44kRdqTwlkIfRD4',
#    'zip_codes': ['1902']},
#   {'name': 'Alltown Car Wash',
#    'address': '525 Paradise Rd, Swampscott',
#    'goog_rating': 1,
#    'lat': 42.4844014,
#    'lng': -70.8997514,
#    'goog_places_id': 'ChIJZ-GSGK8U44kRO_d3eAM3zP0',
#    'zip_codes': ['1902']},
#   {'name': 'Salem Auto Salon',
#    'address': '39 Cabot St, Salem',
#    'goog_rating': 5,
#    'lat': 42.5119371,
#    'lng': -70.8943388,
#    'goog_places_id': 'ChIJ84JNZIgU44kRXwrE_lQDi3I',
#    'zip_codes': ['1902']},
#   {'name': 'Touchfree Car Wash',
#    'address': '290 Canal St, Salem',
#    'goog_rating': 3.7,
#    'lat': 42.501653,
#    'lng': -70.89626729999999,
#    'goog_places_id': 'ChIJ5yIgb5oU44kRej-7JlKaOQ4',
#    'zip_codes': ['1902']},
#   {'name': "Carroll's Boston Street Car Wash",
#    'address': '75 Boston St, Lynn',
#    'goog_rating': 4,
#    'lat': 42.4765135,
#    'lng': -70.9577643,
#    'goog_places_id': 'ChIJEX86MyZt44kR-LCb4fyKw9w',
#    'zip_codes': ['1902']},
#   {'name': 'Black Magic Auto Detailing',
#    'address': '2 Bickerton St, Lynn',
#    'goog_rating': 5,
#    'lat': 42.4725109,
#    'lng': -70.955632,
#    'goog_places_id': 'ChIJbdzyPBlt44kREl5m8MRVd0o',
#    'zip_codes': ['1902']},
#   {'name': 'Finish Line Car Wash',
#    'address': '540 Winthrop St, Taunton',
#    'goog_rating': 4.1,
#    'lat': 41.8817871,
#    'lng': -71.1540455,
#    'goog_places_id': 'ChIJV2h6ARD15IkRFeWHGYzejOE',
#    'zip_codes': ['2780']},
#   {'name': 'Car Wash Queen',
#    'address': '109 W Water St, Taunton',
#    'goog_rating': 4.6,
#    'lat': 41.8861304,
#    'lng': -71.0901932,
#    'goog_places_id': 'ChIJh7bKAqfz5IkR9mfGpqFx8UQ',
#    'zip_codes': ['2780']},
#   {'name': 'Prestige Car Wash',
#    'address': '13 Cape Rd, Taunton',
#    'goog_rating': 4.6,
#    'lat': 41.90514,
#    'lng': -71.066614,
#    'goog_places_id': 'ChIJfWvvWM-M5IkROVPKd5e5qgM',
#    'zip_codes': ['2780']},
#   {'name': "Quick N' Clean",
#    'address': '175 Broadway, Taunton',
#    'goog_rating': 4.1,
#    'lat': 41.9160671,
#    'lng': -71.0908206,
#    'goog_places_id': 'ChIJPWBF0KOM5IkRpVRbNKD-S0I',
#    'zip_codes': ['2780']},
#   {'name': 'County Street Car Wash',
#    'address': '610 County St, Taunton',
#    'goog_rating': 3.8,
#    'lat': 41.8861721,
#    'lng': -71.0671287,
#    'goog_places_id': 'ChIJ39lz_znz5IkRhkPKEIS8neQ',
#    'zip_codes': ['2780']},
#   {'name': 'Magic Car Wash',
#    'address': '342 Winthrop St, Taunton',
#    'goog_rating': 5,
#    'lat': 41.8874561,
#    'lng': -71.1259591,
#    'goog_places_id': 'ChIJc7CBzXX15IkR_pmyVHjdz8U',
#    'zip_codes': ['2780']},
#   {'name': 'Alltown Car Wash',
#    'address': '1266 Broadway, Raynham',
#    'goog_rating': 4,
#    'lat': 41.9625618,
#    'lng': -71.0688906,
#    'goog_places_id': 'ChIJAQrluzyM5IkRVh0BzKuQbJs',
#    'zip_codes': ['2780']},
#   {'name': 'High Performance Inc',
#    'address': '540 Winthrop St, Taunton',
#    'goog_rating': 3.9,
#    'lat': 41.8818019,
#    'lng': -71.1539835,
#    'goog_places_id': 'ChIJS_aLKgX15IkRxCxahMWs5b8',
#    'zip_codes': ['2780']},
#   {'name': "Soogie's Carwash",
#    'address': "241 Monsignor O'Brien Highway, Cambridge",
#    'goog_rating': 2.3,
#    'lat': 42.37344220000001,
#    'lng': -71.0807057,
#    'goog_places_id': 'ChIJ-wiWu_xx44kRVu8VzSm_Kpo',
#    'zip_codes': ['2149']},
#   {'name': 'ScrubaDub Car Wash',
#    'address': '2 Fulbright St, Medford',
#    'goog_rating': 0,
#    'lat': 42.4037042,
#    'lng': -71.097825,
#    'goog_places_id': 'ChIJ0yDds19344kRYsM1kax4fUA',
#    'zip_codes': ['2149']},
#   {'name': 'Bradford Auto Wax',
#    'address': '75 State St, Boston',
#    'goog_rating': 4.7,
#    'lat': 42.35861999999999,
#    'lng': -71.055267,
#    'goog_places_id': 'ChIJmdUhhYZw44kRdV6ho6zVRo0',
#    'zip_codes': ['2149']},
#   {'name': 'Shell',
#    'address': "239 Monsignor O'Brien Highway, Cambridge",
#    'goog_rating': 2.9,
#    'lat': 42.3735159,
#    'lng': -71.0810748,
#    'goog_places_id': 'ChIJ9cN56Lhw44kR0fdQjdnSM_8',
#    'zip_codes': ['2149']},
#   {'name': 'Dr. Detail Hand Car Wash',
#    'address': '100 Cambridgeside Pl, Cambridge',
#    'goog_rating': 4.4,
#    'lat': 42.3681384,
#    'lng': -71.0757011,
#    'goog_places_id': 'ChIJmWpEsr1w44kRC2MfydXa_nw',
#    'zip_codes': ['2149']},
#   {'name': 'Dads Auto Detailing Services',
#    'address': '55 Franklin St, Cambridge',
#    'goog_rating': 4.8,
#    'lat': 42.3614735,
#    'lng': -71.0999399,
#    'goog_places_id': 'ChIJ4y5yHFV344kRMtihxec3LTI',
#    'zip_codes': ['2149']},
#   {'name': 'Diamond Detail & Polish',
#    'address': '62 Nay St, Boston',
#    'goog_rating': 3.5,
#    'lat': 42.3829536,
#    'lng': -71.0380401,
#    'goog_places_id': 'ChIJM9ecC1Jw44kRPF6P6c8HGdk',
#    'zip_codes': ['2149']},
#   {'name': 'Lucca Auto Detailing',
#    'address': '53 Broadway, Malden',
#    'goog_rating': 5,
#    'lat': 42.4249526,
#    'lng': -71.0416996,
#    'goog_places_id': 'ChIJT14qHhpz44kRdQ3Bc0c3LtI',
#    'zip_codes': ['2149']}],
#  'num_results': 119,
#  'num_zip_codes': 13}
